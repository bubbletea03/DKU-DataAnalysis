# %%
import pandas as pd
import matplotlib.pyplot as plt
# 폰트 오류 해결 코드 ↓
from matplotlib import font_manager, rc
font_path = "./malgun.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

FILE_PATH = "./e스포츠_총상금순위.csv"
df = pd.read_csv(FILE_PATH, encoding='cp949')
print(df)
# Out:
#       순위                    국가           상금    선수 수
# 0      1                 China  33593525.88  1571.0
# 1      2         United States  25348153.21  3050.0
# 2      3     Korea Republic of  10952692.63   882.0
# 3      4    Russian Federation   8711577.02   634.0
# 4      5                Brazil   8666555.72  1089.0
# ..   ...                   ...          ...     ...
# 129  130               Senegal       248.41     NaN
# 130  131           Isle of Man        51.00     NaN
# 131  132         New Caledonia        25.00     NaN
# 132  133               Andorra        12.00     NaN
# 133  134   Virgin Islands U.S.        12.00     NaN
#
# [134 rows x 4 columns]

# %%
df.set_index('국가', inplace=True)
print(df)
# Out:
#                        순위           상금    선수 수
# 국가
#  China                  1  33593525.88  1571.0
#  United States          2  25348153.21  3050.0
#  Korea Republic of      3  10952692.63   882.0
#  Russian Federation     4   8711577.02   634.0
#  Brazil                 5   8666555.72  1089.0
# ...                   ...          ...     ...
#  Senegal              130       248.41     NaN
#  Isle of Man          131        51.00     NaN
#  New Caledonia        132        25.00     NaN
#  Andorra              133        12.00     NaN
#  Virgin Islands U.S.  134        12.00     NaN
#
# [134 rows x 3 columns]

# %%
plt.style.use('ggplot')
prizes = df['상금']
prizes = prizes.head(5)
prizes.plot(kind='barh')
plt.gca().invert_yaxis()
plt.title("e스포츠 상금 순위")
plt.ylabel(None)
# Out:
# Text(0, 0.5, '')

# %%
plt.style.use('ggplot')
players = df['선수 수']
players = players.head(10)
players.plot(kind='pie', autopct='%.0f%%')
plt.title("선수 수")
plt.ylabel(None)
# Out:
# Text(0, 0.5, '')
